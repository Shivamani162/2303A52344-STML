# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivamani162/2303A52344-STML/blob/main/Linear_Reression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/Student_performance_data _.csv',usecols=(['Age', 'Gender']))
data.head()
#print(data)
data.shape
#data.info()
data.describe()
data.skew()
data.kurt()
# Out:
# Age      -1.372099
# Gender   -1.999779
# dtype: float64

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
plt.plot(data, color='r')
plt.show()

# %%
x=data.drop('Gender',axis=1)
y=data.Gender
from sklearn import linear_model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1913, 1)
# (479, 1)
# (1913,)
# (479,)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
reg.intercept_
reg.coef_
# Out:
# array([0.01763948])

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([0.54359116, 0.50831221, 0.54359116, 0.52595168, 0.54359116,
#        0.50831221, 0.49067273, 0.49067273, 0.50831221, 0.50831221,
#        0.49067273, 0.49067273, 0.50831221, 0.49067273, 0.49067273,
#        0.50831221, 0.50831221, 0.50831221, 0.49067273, 0.50831221,
#        0.50831221, 0.49067273, 0.54359116, 0.50831221, 0.49067273,
#        0.49067273, 0.52595168, 0.50831221, 0.49067273, 0.49067273,
#        0.49067273, 0.54359116, 0.49067273, 0.52595168, 0.49067273,
#        0.49067273, 0.49067273, 0.49067273, 0.49067273, 0.49067273,
#        0.50831221, 0.50831221, 0.49067273, 0.49067273, 0.50831221,
#        0.49067273, 0.50831221, 0.52595168, 0.54359116, 0.54359116,
#        0.54359116, 0.49067273, 0.50831221, 0.49067273, 0.54359116,
#        0.52595168, 0.50831221, 0.49067273, 0.54359116, 0.50831221,
#        0.54359116, 0.50831221, 0.49067273, 0.52595168, 0.50831221,
#        0.52595168, 0.49067273, 0.54359116, 0.52595168, 0.54359116,
# ...

# %%
y_test
# Out:
# 289     0
# 1287    0
# 322     1
# 820     1
# 252     0
#        ..
# 1302    1
# 1501    0
# 283     0
# 1484    0
# 1890    1
# Name: Gender, Length: 479, dtype: int64

# %%
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error: 0.4991944747330938
# Mean Squared Error: 0.24981028528976543
