# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivamani162/2303A52344-STML/blob/main/Copy_of_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from google.colab import drive
drive.mount('/content/drive')
csv_file_path = '/content/drive/My Drive/Salary_Data.csv'
data = pd.read_csv(csv_file_path)
print(data.head())
X = data[['YearsExperience']]
y = data['Salary']
plt.scatter(X, y, color='blue')
plt.title('Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
test_sizes = [0.2, 0.25]
for test_size in test_sizes:
  print(f"\nTest size: {int(test_size * 100)}%")
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.scatter(X, y, color='blue')
plt.plot(X_test, y_pred, color='red')
plt.title(f'Best Fit Line (Test Size: {int(test_size * 100)}%)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"MSE: {mse}")
print(f"MAE: {mae}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# Test size: 20%
#
# Test size: 25%
# MSE: 38802588.99247065
# MAE: 5056.995466663592

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
data_dict = {
'Feature 1': [1.2, 2.4, 3.5, 4.1, 1.9, 3.7, 2.1, 3.3, 2.8, 4.0],
'Feature 2': [2.3, 1.9, 2.7, 3.0, 2.8, 2.5, 3.2, 2.4, 3.1, 3.3],
'Feature 3': [3.1, 2.8, 1.5, 3.6, 2.5, 1.9, 2.2, 3.0, 1.8, 2.7],
'Feature 4': [4.2, 3.5, 2.9, 4.8, 3.2, 4.0, 4.1, 4.5, 3.6, 4.9],
'Target': [15.6, 13.1, 12.4, 18.2, 14.1, 16.0, 14.5, 17.3, 14.9, 19.2]
}
data = pd.DataFrame(data_dict)
X = data[['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4']]
y = data['Target']
plt.scatter(X['Feature 1'], y, color='blue')
plt.title('Feature 1 vs Target')
plt.xlabel('Feature 1')
plt.ylabel('Target (Y)')
plt.show()
test_sizes = [0.2, 0.3]
for test_size in test_sizes:
  print(f"\nTest size: {int(test_size * 100)}%")
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual')
plt.scatter(range(len(y_test)), y_pred, color='red', label='Predicted')
plt.title(f'Actual vs Predicted (Test Size: {int(test_size * 100)}%)')
plt.xlabel('Data Points')
plt.ylabel('Target (Y)')
plt.legend()
plt.show()
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"MSE: {mse}")
print(f"MAE: {mae}")
# Out:
# Test size: 20%
#
# Test size: 30%
# MSE: 0.8283376869765737
# MAE: 0.8651731636820733
